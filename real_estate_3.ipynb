# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Сергей, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# ### Ответ

# %% [markdown]
# <div class="alert alert-info">Извиняюсь, но на совсем понял данный комментарий. Весь код перед отправкой проверен и рабочий. Приведенный фрагмент также рабочий. Как сказано в описании, он последовательно запрашивает параметры для выборки. после этого выдает анализ. Описание, графики попарной зависимости и таблицу корреляции. На приведенном скрине код запрашивает первый параметр и указывает рекомендуемые границы для данного параметра. Есть объяснение как следует поступить. Можно указать диапазон в рекомендуемых границах. А можно зафиксировать одно значение. Н-р только 5 этажки.</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Привет! Похоже, что в твоем коде предусмотрен ввод значений пользователем вручную. Однако, в рамках написания кода для формирования тестовых данных или анализа, обычно предпочтительнее использовать автоматическую обработку и ввод необходимых числовых значений, чтобы оптимизировать процесс анализа.
#
# В этом случае, стоит внести изменения в код, чтобы числовые значения подставлялись автоматически, без ручного ввода. Такой подход повысит эффективность и удобство анализа. Если возникнут вопросы или нужна помощь с оптимизацией кода, дай мне знать.

# %% [markdown]
# <div class="alert alert-info">Это дополнительный блок кода, не входящий в основной проект. Его смысл именно в ручном вводе параметров, для того, чтобы провести анализ не по всему объему квартир, а выделить какой-то узкий срез. На усмотрение пользователя. Можно провести анализ по 5 этажкам. 9 этажкам. 1-2-3 комнатных квартирах. Квартиры, на определенном удалении. То есть это интерактивный код для формирования строго определенной выборки. Так как возможно огромное сочетание параметров, процесс устроен путем опроса пользователя об интересующем срезе. Данный фрагмент является модификацией или доработкой исходного проекта. Если смущает его присутствие, я могу его закоментарить или удалить. Но мне казалось он очень хорошо дополняет основной блок. Повторюсь, весь требуемый анализ проведен в должном виде и без запроса к пользователю. Это дополниттельный блок.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Спасибо, что обосновал) Теперь я понял твой ход мыслей

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Задача определить рыночную стоимость объектов недвижимости. Для этого проведем исследовательский анализ данных и установим параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# ### Ход исследования

# %% [markdown]
# <div class="alert alert-info">Данные о недвижимости я получу из файла "/datasets/real_estate.csv". О качестве данных мне ничего не известно. Поэтому перед тем как приступить к целям исследования понадобится обзор данных. Я проверю данные на ошибки и оценю Их влияние на исследование. Затем на этапе предобработки я поищу возможность исправить все ошибки данных, которые не приведут к искажению конечного результата. Далее, создам необходимые столбцы, и приступлю к проведению исследовательской анализа. Таким образом, все исследование пройдет в 7 этапов: обзор данных, пред обработка данных, расчеты и добавления результатов в таблицу, проведение анализа для Ленинградской области, проведение анализа для Санкт Петербурга. Различаются ли факторы, которые влияют на ценообразование стоимости квартир. Написание общего вывода </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# Нам предоставлены данные сервиса Яндекс Недвижомость-архив объявлений о продаже недвидимости в Санкт-Петербурге и области. Задача проекта - выявить какие факторы влияют на цену недвижимости.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd
import matplotlib.pyplot as plt

# data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# print(data.head(20))
# data.info()
# data.value_counts()
# data.hist(figsize=(15,20))

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

display(data.head(20))
data.info()
data.value_counts()
data.hist(figsize=(15,20))
plt.show()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# А для чего тут decimal?

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Предлагаю разделять логически разные вещи:
#
#     - импорты библиотек
#     - открытие данных (это может быть не тривиальный процесс)
#     - рабочий код
#
# Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок если они есть и исключит повторное выполнение кода

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
# Такие предупреждения можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку `matplotlib.pyplot as plt`
# 2. В конец кода добавить `;`
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы как нибудь прокомментировать полученные данные в разделе
# </div>

# %% [markdown]
# <div class="alert alert-info">Проверим датафрейм на явные дубликаты</div>

# %%
duplicates = data[data.duplicated()]
print('Явные дубликаты:')
print (duplicates)
# Out:
# Явные дубликаты:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-info"> Явных дубликатов нет </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Проверить на сумму дубликатов можно вот так:
#
#     df.duplicated().sum()

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Выполните предобработку данных

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %% [markdown]
# Найдите и изучите пропущенные значения в столбцах:
# Определите, в каких столбцах есть пропуски.
# Заполните пропущенные значения там, где это возможно. Например, если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски можно заменить на число 0. Если логичную замену предложить невозможно, то оставьте пропуски. Пропущенные значения — тоже важный сигнал, который нужно учитывать.
# В ячейке с типом markdown укажите причины, которые могли привести к пропускам в данных.
# Рассмотрите типы данных в каждом столбце:
# Найдите столбцы, в которых нужно изменить тип данных.
# Преобразуйте тип данных в выбранных столбцах.
# В ячейке с типом markdown поясните, почему нужно изменить тип данных.
# Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.

# %%
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_12ed1_row0_col0,#T_12ed1_row1_col0,#T_12ed1_row2_col0,#T_12ed1_row3_col0,#T_12ed1_row4_col0,#T_12ed1_row6_col0,#T_12ed1_row8_col0,#T_12ed1_row10_col0,#T_12ed1_row11_col0,#T_12ed1_row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_12ed1_row5_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_12ed1_row7_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_12ed1_row9_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_12ed1_row12_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_12ed1_row13_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_12ed1_row15_col0,#T_12ed1_row16_col0,#T_12ed1_row17_col0,#T_12ed1_row19_col0{
#             background-color:  #90b2fe;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-info">Данный код выводит кол-во пропусков в каждом столбце в процентном отношении. Пропуски в расстоянии связаны с тем, что это область. И там фактор удаленности от центра Питера второстепенный. Собственно поэтому я разделяю датасет на 2 и анализирую по отдельности. Пропуски в парках и прудах говорят о том, что их там нет в разумном удалении. </div>

# %% [markdown]
# <div class="alert alert-info">Так как данные в базе бьются на 2 типа - заполненные пользователем и системой, то и пропуски пользователя вполне обьяснимы. Хотя в большинстве стучаев бланк опроса важные параметры делает обязательным к заполнению. Что исключило бы пропуски, но, возможно, добавило бы аномалии. Хотя проверка на аномалии также возможна и система может не пропускать такие значения на этапе заполнения. Гораздо хуже, когда есть пропуски в данных, которые заполняются самой системой. Это должны быть данные:
#  - всего этажей в доме (исходя из адреса)
#  - все возможные расстояния
#  - количество парков и прудов
#  Скорее всего база недостаточно связана с геоданными, что странно. Учитываю насколько сильный сервис "Яндекс.карты"
#  Отдельное удивление вызывает Срок экспозиции. Но тут есть разумное объяснение. Если у объявдения нет закрытого срока, значит объявление еще находится в продаже. И сделав соответсьвующую выборку мы сможем просмотреть актуальную базу объявлений.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Похоже, что твой промежуточный вывод обрывается

# %%
data['balcony'].fillna(0, inplace=True)
data['parks_around3000'].fillna(0, inplace=True)
data['ponds_around3000'].fillna(0, inplace=True)
data['balcony']=data['balcony'].astype('int')
data['parks_around3000'] = data['parks_around3000'].round().astype(int)
data['ponds_around3000'] = data['ponds_around3000'].astype(int)
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
display(data.head())
print(data['balcony'].unique())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0        0  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен, если пропуск - вероятнее всего балкон отсутствует

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Для вывода датасетов корректнее использовать display(), а не print()

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %% [markdown]
# Шаг 3. Добавьте в таблицу новые столбцы со следующими параметрами:
# цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);
# день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# месяц публикации объявления;
# год публикации объявления;
# тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).

# %%
data['locality_name_new'] = data['locality_name'].str.extract(r'([А-ЯЁ].*)')
data['locality_name_new'].value_counts()
# Out:
# Санкт-Петербург    15721
# Мурино               590
# Кудрово              472
# Шушары               440
# Всеволожск           398
#                    ...
# Сижно                  1
# Пчевжа                 1
# Коммунары              1
# Ялгино                 1
# Малая Романовка        1
# Name: locality_name_new, Length: 305, dtype: int64

# %%
data['locality_name_new'].unique()
# Out:
# array(['Санкт-Петербург', 'Шушары', 'Янино-1', 'Парголово', 'Мурино',
#        'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин', 'Кудрово',
#        'Коммунар', 'Колпино', 'Красный Бор', 'Гатчина', 'Фёдоровское',
#        'Выборг', 'Кронштадт', 'Кировск', 'Новое Девяткино',
#        'Металлострой', 'Лебяжье', 'Сиверский', 'Молодцово',
#        'Кузьмоловский', 'Новая Ропша', 'Павловск', 'Пикколово',
#        'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск', 'Сестрорецк',
#        'Куттузи', 'Аннино', 'Ефимовский', 'Плодовое', 'Заклинье',
#        'Торковичи', 'Первомайское', 'Красное Село', 'Понтонный',
#        'Сясьстрой', 'Старая', 'Лесколово', 'Новый Свет', 'Сланцы',
#        'Путилово', 'Ивангород', 'Шлиссельбург', 'Никольское',
#        'Зеленогорск', 'Сосновый Бор', 'Оржицы', 'Кальтино', 'Романовка',
#        'Бугры', 'Рощино', 'Кириши', 'Луга', 'Волосово', 'Отрадное',
#        'Павлово', 'Оредеж', 'Копорье', 'Молодёжное', 'Тихвин', 'Победа',
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Интересная реализация

# %%
for index, row in data.iterrows():
    if pd.isna(row['floors_total']):
        if row['floor']==5:
            data.at[index,'floors_total'] = 5
        else:
            data.at[index,'floors_total'] = row['floor'] + 1
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Молодец, что используешь собственные функции

# %%
data['locality_name_new'] = data['locality_name_new'].fillna('Noname')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Ты выбрал самый правильный способ замены пропусков в категориальном столбце - замена на значение-заглушку

# %% [markdown]
# Долее расчитаем цену кв.м. Для этого разделим last_price на total_area. Предварительно убедимся, что нет нулей, чтоб избежать деления на 0

# %%
data[data['total_area']==0].value_counts()
data['price_m2'] = (data['last_price']/data['total_area']).round(2)

# %% [markdown]
# Введем для последующего анализа день недели, месяц и год подачи объявления.

# %%
data['day_of_week'] = (data['first_day_exposition']).dt.weekday
data['mes_exposition'] = (data['first_day_exposition']).dt.month
data['year_exposition'] = (data['first_day_exposition']).dt.year

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Совет на будущие работы `(в этом проекте этот метод не нужен)`: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#      https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html
#
#     и
#
#     https://www.sharpsightlabs.com/blog/pandas-astype/
# </div>

# %% [markdown]
# Добавим категоризацию для этажа квартиры - первый. последний, другой

# %%
data['type_floor'] = data.apply(
    lambda row:'первый' if row['floor']==1 else 'последний' 
    if row['floor']==row['floors_total'] else 'другой', axis=1)

# %% [markdown]
# Далее расстояние до центра города округлим до 1км

# %%
data['dist'] = (data['cityCenters_nearest']/1000).round(0)

# %% [markdown]
# Попробуем частично убрать пропуски в высоте потолков. Самый большой объем в базе занимают 5 этажки. И по ним довольно узкий диапазон высоты потолков. Исзодя из этого принято решение для 5этажек заменить пропущенные значения в высоте потолка медианой для 5этажек(2.6м). По остальной этажности разброс больше. И нет смысла переносить одну зависимость на другую

# %% [markdown]
# Код не завершен по причине нецелесообразности. Пропущено 958 значений высоты потолка в 5этажках. Их можно заменить на "2.60". Но ни на что в дальнейшем это не повлияет

# %%
miss_balc_count = data[data['floor']==5]['ceiling_height'].isna().sum()
print (miss_balc_count)
data_5 = data[data['floor'] ==5]['ceiling_height']
data_all = data['ceiling_height']
print(data_5.describe())
print(data_all.describe())
#print(data.head(20))
# Out:
# 958
# count    1663.000000
# mean        2.811966
# std         2.582660
# min         1.750000
# 25%         2.500000
# 50%         2.600000
# 75%         2.800000
# max       100.000000
# Name: ceiling_height, dtype: float64
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# В следующем коде рассмотрим отсутствующий расстояние до ближайшего аэропорта. Как показал анализ, все отсутствующие расстояния связаны с областными городами, но не с Санкт Петербургом. Это говорит о том, что для Санкт Петербурга значение проставлялись из геоданных, а а для других городов не сочли нужным этого делать. Оставим так как есть

# %%
miss_airoport = data[data['airports_nearest'].isna()]
miss_airoport['locality_name_new'].value_counts()
# Out:
# Мурино                588
# Кудрово               472
# Всеволожск            398
# Гатчина               307
# Выборг                237
#                      ...
# Севастьяново            1
# Снегирёвка              1
# Большое Рейзино         1
# Рапполово               1
# Большая Пустомержа      1
# Name: locality_name_new, Length: 287, dtype: int64

# %% [markdown]
# В следующем блоке обработаем аномальные значения высоты потолков ааа значение больше 20 м ааа предполагаем что неправильно поставлена,Поэтому там где потолки больше 20 м разделим на 10 значение больше 10 м оставим без изменений потому что непонятно что означает данная аномалия.Далее в анализе были проаналиоированы потолки. Было принято решение, что значения больше 20м заведомо нереальные и видимо ошибка в запятой на один разряд. Поэтому мы все значения от 20м поделим на 10.
# после этого останутся единичные варианты с высотой потолка 14, 10, 8 и т.д. Их уже на 10 не поделить. Тут очевидно ошибка другого рода. Иы их просто исключим из рассмотрения. Их буквально несколько. Нам необходимое преобразование надо сделать уже сейчас т.н. я планирую разделить таблицы на Питер - неПитер

# %%
def transf_value(value):
    if value >=20:
        return value/10
    else:
        return(value)
data['ceiling_height']=data['ceiling_height'].apply(transf_value)
sorted_ceiling = data['ceiling_height'].sort_values(ascending=False)
print(data['ceiling_height'].describe())
print(sorted_ceiling.head(20))
data.info()
# Out:
# count    14504.000000
# mean         2.729608
# std          0.319850
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         14.000000
# Name: ceiling_height, dtype: float64
# 15061    14.00
# 22309    10.30
# 22869    10.00
# 5863      8.30
# 3474      8.00
# 17442     8.00
# 15743     8.00
# 20264     6.00
# 21227     5.80
# 1388      5.60
# 7578      5.50
# 1026      5.30
# 12628     5.30
# 464       5.20
# 1053      5.00
# 21923     4.90
# 2802      4.80
# 19142     4.70
# 1300      4.70
# 12401     4.65
# Name: ceiling_height, dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличная функция

# %% [markdown]
# <div class="alert alert-info">В следующем блоке разобьем базу данных на 2: Санкт-Петербург и не Санкт-Петербург. В дальнейшем при анализе мы увидим разные данные и этим обоснован раздельный анализ для Санкт Петербурга и области. В частности в области нет расстояний до центра города и нет расстояния до аэропорта. Поэтому заведомо анализировать всю информацию корректнее по Санкт-Петербургу. </div>

# %%
data_Piter = data[data['locality_name_new']=='Санкт-Петербург']
data_Piter.info()
data_noPiter = data[data['locality_name_new']!='Санкт-Петербург']
data_noPiter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15721 entries, 0 to 23697
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          15721 non-null  int64
#  1   last_price            15721 non-null  float64
#  2   total_area            15721 non-null  float64
#  3   first_day_exposition  15721 non-null  datetime64[ns]
#  4   rooms                 15721 non-null  int64
#  5   ceiling_height        10104 non-null  float64
#  6   floors_total          15721 non-null  float64
#  7   living_area           14581 non-null  float64
#  8   floor                 15721 non-null  int64
#  9   is_apartment          1833 non-null   object
#  10  studio                15721 non-null  bool
#  11  open_plan             15721 non-null  bool
#  12  kitchen_area          14342 non-null  float64
#  13  balcony               15721 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Не стоит писать весь код в одной ячейке. Лучше так: одна ячейка = одна мысль

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует проверка на явные дубликаты, поправишь, пожалуйста?

# %% [markdown]
# Путем анализа данных пришед к выводу, что таблица объкдиняет очень разнородную информацию. Причем основные пропуски связаны с "неПитером". Исходя из этого считаю рациональным разделить дальнейший анализ на 2 части(или 3). Отдельно рассмореть Питер и неПитер. Это гораздо лучше, чем заполнять половину таблицы медианы и пытаться после этого искать закономерности по всему региону. По Питеру таблица имеет максимально заподеннную информацию и имеет смысл анализировать ее отдеотно от остальной массы. К тому же эти данные составляют 2/3 всей таблицы.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Второй раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Изучите перечисленные ниже параметры объектов и постройте отдельные гистограммы для каждого из этих параметров. В некоторых параметрах встречаются редкие и выбивающиеся значения. При построении гистограмм удалите их. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах, если они есть. Если природа аномалии понятна и данные действительно искажены, то восстановите    корректное значение. В противном случае удалите редкие и выбивающиеся значения.
# Список параметров:
# общая площадь;
# жилая площадь;
# площадь кухни;
# цена объекта;
# количество комнат;
# высота потолков;
# тип этажа квартиры («первый», «последний», «другой»);
# общее количество этажей в доме;
# расстояние до центра города в метрах;
# расстояние до ближайшего парка
# Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.
# Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.
# Постройте гистограмму.
# Посчитайте среднее и медиану.
# В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?
# Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта.
# Изучите, зависит ли цена от:
# общей площади;
# жилой площади;
# площади кухни;
# количества комнат;
# этажа, на котором расположена квартира (первый, последний, другой);
# даты размещения (день недели, месяц, год).
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
# Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра. Учитывайте каждый километр расстояния: узнайте среднюю цену квартир в одном километре от центра, в двух и так далее. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.

# %% [markdown]
# ### общая площадь

# %% [markdown]
# Рассмотрим как выглядит распределение квартир по площади. Также оценим аномальные значения.

# %%
print(data['total_area'].describe())
data['total_area'].hist(range=(0,200),bins=30)
print(data_Piter['total_area'].describe())
data_Piter['total_area'].hist(range=(0,200),bins=30)
print(data_noPiter['total_area'].describe())
data_noPiter['total_area'].hist(range=(0,200),bins=30)
plt.title('Распределение квартир по общей площади')
plt.ylabel('Количество')
plt.xlabel('Общая площадь')
plt.show()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64
# count    15721.000000
# mean        64.751488
# std         40.417095
# min         12.000000
# 25%         42.000000
# 50%         55.000000
# 75%         74.600000
# max        900.000000
# Name: total_area, dtype: float64
# count    7978.000000
# mean       51.672666
# std        21.067982
# min        15.000000
# 25%        37.000000
# 50%        47.000000
# 75%        61.000000
# max       380.000000
# Name: total_area, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что используешь метод range() для определения пиковых значений
# </div>

# %% [markdown]
# Данные по общей площади выглядят более чем корректно. Даже квартира в Питере 900кв.м и 380 в области вполне допустима. Пропусков в данных нет. Выбросов нет. Очень призодная для анализа информация. Отсечка = 200

# %% [markdown]
# ### жилая площадь

# %%
print(data['living_area'].describe())
data['living_area'].hist(range=(0,100),bins=30)
print(data_Piter['living_area'].describe())
data_Piter['living_area'].hist(range=(0,100),bins=30)
print(data_noPiter['living_area'].describe())
data_noPiter['living_area'].hist(range=(0,100),bins=30)
plt.title('Распределение квартир по жилой площади')
plt.ylabel('Количество')
plt.xlabel('Жилая площадь')
plt.show()
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64
# count    14581.000000
# mean        36.959148
# std         24.701374
# min          2.000000
# 25%         19.900000
# 50%         31.300000
# 75%         44.000000
# max        409.700000
# Name: living_area, dtype: float64
# count    7215.000000
# mean       29.402912
# std        13.962146
# min         2.000000
# 25%        18.000000
# 50%        28.000000
# 75%        37.400000
# max       239.400000
# Name: living_area, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Рекомендую оформлять визуализацию подписями осей абсцисс/ординат и заголовки.
#
#     plt.title('Название заголовка')
#     plt.ylabel('Название оси ординат')
#     plt.xlabel('Название оси абсцисс')
#     plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Так держать!)

# %% [markdown]
# Здесь тоже все более менее. Но. В отличие от предыдущей колонки, здесь уже есть пропуски. Заполнить эти пропуски можно посчитав усредненную долю жилой площади в общей. И таким образом достаточно корректно и обоснованно избавиться от пропусков. Но пока необходимости в этом не видно. Отсечка = 200

# %% [markdown]
# ### площадь кухни

# %%
print(data['kitchen_area'].describe())
data['kitchen_area'].hist(range=(0,40),bins=30)
print(data_Piter['kitchen_area'].describe())
data_Piter['kitchen_area'].hist(range=(0,40),bins=30)
print(data_noPiter['kitchen_area'].describe())
data_noPiter['kitchen_area'].hist(range=(0,40),bins=30)
plt.title('Распределение квартир по площади кухни')
plt.ylabel('Количество')
plt.xlabel('Площадь кухни')
plt.show()
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64
# count    14342.000000
# mean        11.155806
# std          6.543392
# min          1.300000
# 25%          7.200000
# 50%          9.900000
# 75%         12.500000
# max        112.000000
# Name: kitchen_area, dtype: float64
# count    7079.000000
# mean        9.382578
# std         4.084416
# min         2.300000
# 25%         6.600000
# 50%         8.900000
# 75%        10.900000
# max        64.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Здесь тоже все более менее. Но. В отличие от предыдущей колонки, здесь уже есть пропуски. Заполнить эти пропуски можно посчитав усредненную долю жилой площади в общей.
# И таким образом достаточно корректно и обоснованно избавиться от пропусков. Но пока необходимости в этом не видно.
# Отсечка = 40

# %% [markdown]
# ### цена объекта

# %%
print(data['last_price'].describe())
data['last_price'].hist(range=(0,25000000),bins=30)
print(data_Piter['last_price'].describe())
data_Piter['last_price'].hist(range=(0,25000000),bins=30)
print(data_noPiter['last_price'].describe())
data_noPiter['last_price'].hist(range=(0,25000000),bins=30)
print (data['last_price'].sort_values(ascending=False))
plt.title('Распределение квартир по цене')
plt.ylabel('Количество')
plt.xlabel('Цена')
plt.show()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64
# count    1.572100e+04
# mean     8.062507e+06
# std      1.301313e+07
# min      1.219000e+04
# 25%      4.200000e+06
# 50%      5.500000e+06
# 75%      8.160000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64
# count    7.978000e+03
# mean     3.544434e+06
# std      2.204650e+06
# min      4.300000e+05
# 25%      2.350000e+06
# 50%      3.200000e+06
# 75%      4.200000e+06
# max      4.200000e+07
# Name: last_price, dtype: float64
# 12971    763000000.0
# 19540    420000000.0
# 14706    401300000.0
# 1436     330000000.0
# 15651    300000000.0
#             ...
# 16219       450000.0
# 16274       440000.0
# 17456       430000.0
# 14911       430000.0
# 8793         12190.0
# Name: last_price, Length: 23699, dtype: float64

# %% [markdown]
# Здесь присутствуют несколько очень дорогих квартир. Скорее всего это реальные данные, но они сильно портят статистику.
# И можно их исключить из рассмотрени или выделить в отдельную категорию. Отческа = 100млн

# %% [markdown]
# ### количество комнат

# %%
print(data['rooms'].describe())
data['rooms'].hist(range=(0,5),bins=30)
print(data_Piter['rooms'].describe())
# data_Piter['rooms'].hist(range=(0,5),bins=30)
# print(data_noPiter['rooms'].describe())
# data_noPiter['rooms'].hist(bins=30, range=(0,5))
# display (data['rooms'].sort_values(ascending=False))
filt_data = data[data['rooms'].between(0,5)]
grouped_data = filt_data.groupby('rooms').count()
grouped_data.plot(kind = 'bar', legend = False )
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64
# count    15721.000000
# mean         2.171618
# std          1.148098
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64
# <AxesSubplot:xlabel='rooms'>

# %% [markdown]
# Здесь можно безболезненно ограничиться 5 комнатами. Непонятно обилие цветных линий на графике

# %% [markdown]
# ### высота потолков

# %%
print(data['ceiling_height'].describe())
data['ceiling_height'].hist(range=(2,4), bins=30)
print(data_Piter['ceiling_height'].describe())
data_Piter['ceiling_height'].hist(range=(2,4), bins=30)
print(data_noPiter['ceiling_height'].describe())
data_noPiter['ceiling_height'].hist(range=(2,4), bins=30)
print (data['ceiling_height'].sort_values(ascending=False))
plt.title('Распределение квартир по высоте потолков')
plt.ylabel('Количество')
plt.xlabel('Высота потолков')
plt.show()

# data['ceiling_height'].hist(range=(0,4),bins=30)
# data_Piter['ceiling_height'].hist(bins=30)
# Out:
# count    14504.000000
# mean         2.729608
# std          0.319850
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         14.000000
# Name: ceiling_height, dtype: float64
# count    10104.000000
# mean         2.767358
# std          0.346685
# min          1.000000
# 25%          2.550000
# 50%          2.700000
# 75%          2.850000
# max         14.000000
# Name: ceiling_height, dtype: float64
# count    4400.000000
# mean        2.642918
# std         0.224629
# min         1.200000
# 25%         2.500000
# 50%         2.600000
# 75%         2.700000
# max         8.000000
# Name: ceiling_height, dtype: float64
# 15061    14.0
# 22309    10.3
# 22869    10.0
# 5863      8.3
# 3474      8.0
#          ...
# 23687     NaN
# 23690     NaN
# 23692     NaN
# 23695     NaN
# 23696     NaN
# Name: ceiling_height, Length: 23699, dtype: float64

# %% [markdown]
# Здесь надо последовательно отбрасывать значения. 100 - удалить или заменить на медиану. 27 - 32 поделить на 10. Провел отдельный анализ по заполнению пропуков в потолках. Сразу отбросил идею заполнения медианой. У нас пропущено треть значений. И заполнив таким образом мы только потеряем зависимость, котора возможно была. Гораздо умнее сделать следующее. У нас есть явный пики по количеству 5 и 9 этажек. Я провел анализ высотности потолков по существующим данным и получил что у них также есть характерные пики. И вот ими стоит заполнить пропущенные значения для 5 и 9 этажек. Для остальных это лишено смысла поскольку у них нет нарактерного масимума и довольна размыта картина по высотам.

# %% [markdown]
# ### тип этажа квартиры

# %%
print(data['type_floor'].describe())
data['type_floor'].hist(bins=30)
print(data_Piter['type_floor'].describe())
data_Piter['type_floor'].hist(bins=30)
print(data_noPiter['type_floor'].describe())
data_noPiter['type_floor'].hist(bins=30)
print (data['type_floor'].sort_values(ascending=False))
# Out:
# count      23699
# unique         3
# top       другой
# freq       17442
# Name: type_floor, dtype: object
# count      15721
# unique         3
# top       другой
# freq       12217
# Name: type_floor, dtype: object
# count       7978
# unique         3
# top       другой
# freq        5225
# Name: type_floor, dtype: object
# 10926    последний
# 12154    последний
# 16405    последний
# 16403    последний
# 8698     последний
#            ...
# 3752        другой
# 11742       другой
# 3750        другой
# 3749        другой
# 0           другой
# Name: type_floor, Length: 23699, dtype: object

# %% [markdown]
# непонятно, что тут надо анализировать. Все нормально. Категориальная переменная. Очевидно понадобится в дальнейшем при поиске взаимосвязей.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %% [markdown]
# ### общее количество этажей в доме

# %%
print(data['floors_total'].describe())
data['floors_total'].hist(range=(0,30),bins=30)
print(data_Piter['floors_total'].describe())
data_Piter['floors_total'].hist(range=(0,30),bins=30)
print(data_noPiter['floors_total'].describe())
data_noPiter['floors_total'].hist(range=(0,30),bins=30)
print (data['floors_total'].sort_values(ascending=False))
plt.title('Распределение квартир по кол-ву этажей в доме')
plt.ylabel('Количество квартир')
plt.xlabel('Кол-во этажей в доме')
plt.show()
# Out:
# count    23699.000000
# mean        10.674923
# std          6.595852
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64
# count    15721.000000
# mean        11.395204
# std          6.371781
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         52.000000
# Name: floors_total, dtype: float64
# count    7978.000000
# mean        9.255578
# std         6.797026
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%        12.000000
# max        60.000000
# Name: floors_total, dtype: float64
# 2253     60.0
# 16731    52.0
# 16934    37.0
# 5807     36.0
# 11079    36.0
#          ...
# 16444     1.0
# 14836     1.0
# 10817     1.0
# 7962      1.0
# 8388      1.0
# Name: floors_total, Length: 23699, dtype: float64

# %% [markdown]
# два явных пика. 5 и 9 этажей. На 30 этажах можно ставить отсечку.

# %% [markdown]
# ### расстояние до центра города в метрах

# %%
print(data['cityCenters_nearest'].describe())
data['cityCenters_nearest'].hist(bins=30)
print(data_Piter['cityCenters_nearest'].describe())
data_Piter['cityCenters_nearest'].hist(bins=30)
print(data_noPiter['cityCenters_nearest'].describe())
data_noPiter['cityCenters_nearest'].hist(bins=30)
print (data['cityCenters_nearest'].sort_values(ascending=False))
plt.title('Распределение квартир по расстоянию от центра')
plt.ylabel('Количество')
plt.xlabel('Расстояние,м')
plt.show()
# Out:
# count    18180.000000
# mean     14191.277833
# std       8608.386210
# min        181.000000
# 25%       9238.000000
# 50%      13098.500000
# 75%      16293.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64
# count    15660.000000
# mean     11601.291571
# std       4842.035279
# min        181.000000
# 25%       8327.000000
# 50%      12244.500000
# 75%      14943.000000
# max      29493.000000
# Name: cityCenters_nearest, dtype: float64
# count     2520.00000
# mean     30286.19246
# std       9391.31892
# min       1322.00000
# 25%      24302.00000
# 50%      30308.50000
# 75%      33633.75000
# max      65968.00000
# Name: cityCenters_nearest, dtype: float64
# 9640     65968.0
# 5340     65952.0
# 577      65764.0
# 20746    65105.0
# 5218     64857.0
#           ...
# 23683        NaN
# 23692        NaN
# 23695        NaN
# 23696        NaN
# 23698        NaN
# Name: cityCenters_nearest, Length: 23699, dtype: float64

# %% [markdown]
# Здесь прямо явно видна необходимость рассматривать отдельно Питер и не Питер. Данные праетически не пересекаются и по сути дают разные ланные для анализа. Во всех графиках - синий цвет - общий датасет. Оранжевый - Питер. Зеленый - Область

# %% [markdown]
# ### расстояние до ближайщего парка

# %%
print(data['parks_nearest'].describe())
data['parks_nearest'].hist(bins=30)
print(data_Piter['parks_nearest'].describe())
data_Piter['parks_nearest'].hist(bins=30)
print(data_noPiter['parks_nearest'].describe())
data_noPiter['parks_nearest'].hist(bins=30)
print (data['parks_nearest'].sort_values(ascending=False))
plt.title('Распределение квартир по расстоянию до ближ. парка')
plt.ylabel('Количество')
plt.xlabel('Расстояние до парка,м')
plt.show()
# Out:
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64
# count    7284.000000
# mean      498.597886
# std       345.181284
# min         1.000000
# 25%       295.000000
# 50%       460.000000
# 75%       619.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64
# count     795.000000
# mean      419.400000
# std       305.958725
# min         4.000000
# 25%       228.000000
# 50%       376.000000
# 75%       531.000000
# max      2131.000000
# Name: parks_nearest, dtype: float64
# 10959    3190.0
# 19430    3190.0
# 1590     3064.0
# 19208    3013.0
# 23080    2984.0
#           ...
# 23691       NaN
# 23692       NaN
# 23695       NaN
# 23696       NaN
# 23698       NaN
# Name: parks_nearest, Length: 23699, dtype: float64

# %% [markdown]
# Данная выборка за счет своей малочисленности представляет довольно умозрительный интерес. Хотя для определенной категории (типа меня н-р :)представляет определяющее значение. Подавляюшая выборка укладывается в 500м. Это очень хорошо. Даже слищком. В раельной жизни парк в радиусе 1 км это очень хорошо. Это позволяет сделать предположение, что у остальной 2/3 таблицы нет парка в разумеой удаленности так, чтоб об этом имело смысл упомянуть.

# %% [markdown]
# ### Срок экспозиции

# %%
print(data['days_exposition'].describe())
data['days_exposition'].hist(range=(40,100),bins=60)
print(data_Piter['days_exposition'].describe())
data_Piter['days_exposition'].hist(range=(40,100),bins=60)
print(data_noPiter['days_exposition'].describe())
data_noPiter['days_exposition'].hist(range=(40,100),bins=60)
print (data['days_exposition'].sort_values(ascending=False))
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
# count    13638.000000
# mean       182.792198
# std        224.719204
# min          1.000000
# 25%         42.000000
# 50%         95.000000
# 75%        231.000000
# max       1572.000000
# Name: days_exposition, dtype: float64
# count    6880.000000
# mean      177.115262
# std       209.447700
# min         3.000000
# 25%        45.000000
# 50%        96.000000
# 75%       232.000000
# max      1580.000000
# Name: days_exposition, dtype: float64
# 18843    1580.0
# 1109     1572.0
# 9553     1553.0
# 1885     1513.0
# 20969    1512.0
#           ...
# 23684       NaN
# 23685       NaN
# 23694       NaN
# 23696       NaN
# 23698       NaN
# Name: days_exposition, Length: 23699, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Давай тут уменьшим range до 100 или 200 (ведь именно в эти дни происходят основные продажи), возможно тут есть интересные аномалии. Так же в таких моментах лучше делать колличество корзин = колличеству дней (в соответствии с range)
# </div>

# %% [markdown]
# <div class="alert alert-info">Согласно рекомендации изменил range и bin. Это позволило обнаружить несколько пиков по срокам (46, 60,90). Честно говоря, никаких разумных объяснений не могу придумать. Единственное, что в эти дни происходит снижение цены согласно договоренности с агентом. Но это очень слабое предположение. Агентов много и единой схемы продажи сложно предположить. Можно еще предположить, что это срок хранения объявления. После которого база требует продления с оплатой. И соответственно продавцы снимают свои объявления. И поэтому есть такие пики по сроку экспонирования. Но это тоже слабое предположение, поскольку главный пик на 46й день.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
#
#
# Эти аномалии очень похожи на техническую особенность самой платформы: вероятнее, в эти дни платформа автоматически убирает объявления, если пользователь его не продлил
# </div>

# %% [markdown]
# Здесь на удивление все совпадает. Средний срок экспозиции - 95 дней. В городе и области. 75% квартир продается за 7,5мес. Есть категория квартир, которая продается по 5 лет )За счет них средняя практически вдвое превышает медиану.182. Бвстрыми я бы назвал продажу быстрее 1го квартиля. А именно -45 дней. Додго это больше 230 дней. С т. зрения продавца очевидный повод подумать, что что то не так с соотношением квартира/цена. Хотя на более низких сроках уже имеет смысл проанализировать объявление на предмет его корректности и алекватности.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Да, до 1.5 месяцев можно назвать быстрой продажей

# %% [markdown]
# ## Определение факторов, влияющих на цену

# %% [markdown]
# ### Цена от общей площади

# %%
data.plot(x='last_price', y='total_area', xlim=(0, 10000000), ylim=(20,100),
          kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
print (data['total_area'].corr(data['last_price']))
print (data['total_area'].corr(data['price_m2']))
# Out:
# 0.6536750579657242
# 0.30196021032713416

# %% [markdown]
# Анализируем сразу 2 ценовых параметра. Общую стоимость и цену кв.м. Цена кв.м более интересна. Здесь наблюдаем очень высокую взаимосвязь. Что довольно логично. Но. Как только мы перейдем от рассмотрения обшей цены к цене кв.м зависимость уменьшится вдвое. Тем не менее она остается довольно высокой.Локальные пики соответствуют 1 и 2х комнатным квартирам в 5 и 9 этажках.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что зависимость нелинейных данных рассматриваешь через тип графика scatter
# </div>

# %% [markdown]
# ### Цена от жилой площади

# %%
data.plot(x='last_price', y='living_area', xlim=(0,12000000), ylim=(0,100),
          kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
print (data['living_area'].corr(data['last_price']))
print (data['living_area'].corr(data['price_m2']))
# Out:
# 0.5664915336952651
# 0.22634649083379818

# %% [markdown]
# <div class="alert alert-info">Здесь мы наблюдаем аналогичную зависимость. Что также вполне предсказуемо. Наблюдаем 3 пиковых значения. 17, 30, 42 кв.м. Эти пики легко объяснимы. Подавляющее большинство квартир в продаже - это типовые 1,2,3 комнатные квартиры в 5 и 9 этажках. Соотвественно эти пики соответствуют жилой площади в этих 1,2,3 комнатных квартирах</div>

# %% [markdown]
# ### Цена от площади кухни

# %%
data.plot(x='last_price', y='kitchen_area', xlim=(0, 10000000), ylim=(5,15),
          kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
print (data['kitchen_area'].corr(data['last_price']))
print (data['kitchen_area'].corr(data['price_m2']))
# Out:
# 0.5198690130216392
# 0.39749342300740254

# %% [markdown]
# <div class="alert alert-info">Выводы и зависимости полностью совпадают с предыдушими оценками площадей. Пики соответствуют типовому жилью.</div>

# %% [markdown]
# ### Цена от количества комнат

# %%
data.plot(x='last_price', y='rooms', xlim=(0, 25000000), ylim=(0,5),
          kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
print (data['rooms'].corr(data['last_price']))
print (data['rooms'].corr(data['price_m2']))
# Out:
# 0.3633428499648948
# 0.05541965622941345

# %%
filt_data = data[data['rooms'].between(0,5)]
grouped_data = filt_data.groupby('rooms')['last_price'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['rooms'],grouped_data['last_price'])
plt.title('Средняя цена в зависимости от количества комнат(0-5)')
plt.xlabel('Кол-во комнат')
plt.ylabel('Средняя цена')
plt.show()

# %%
filt_data = data[data['rooms'].between(0,5)]
grouped_data = filt_data.groupby('rooms')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['rooms'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от количества комнат(0-5)')
plt.xlabel('Кол-во комнат')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-info">Анализ цены кв.м. гораздо интереснее. Явный минимум на 2-3 комнатных квартирах. Как неоднократно звучало ранее, это типовые маламетражные кв. в старых 5 и 9 этажных домах. Несмотря на их подовляющее большинство, они морально устарели. Поэтому 4 и 5 комнатные квартиры в новых домах и они гораздо интереснее. 1 комнатные квартиры дороже поскольку это самое дешевое жилье и при этом уже отдельная квартира. Поэтому тут высокий порог входа по сравнению с комнатой в комуналке. Когда речь идет о 0 комнатах это очень интересное жилье. Нетиповое и дизайнерское. Это студии или что-то переделанное из нежилого фонда. Это крайне малочисленная категория и , понятно, что она дороже типовых 1-2-3 квартир. При этом не дотягивает до цены современных 4-5 комнатных квартир с хорошей планировкой </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Корреляцию есть смысл рассчитывать только для нелинейных данных (в нашем случае это площади)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Зависимости дискретных данных (тип этажа, месяц, комнаты) лучше рассмотреть на линейной или столбчатой диаграмме (сгруппировав предварительно)
# </div>

# %% [markdown]
# ### Цена от типа этажа квартиры (первый, последний, другой)

# %%
# data.plot(x='last_price', y='type_floor', xlim=(0, 25000000), ylim=(0,3),
#           kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
# print (data['type_floor'].corr(data['last_price']))

# %%
# data.plot(x='last_price', y='day_of_week', xlim=(0, 25000000), ylim=(0,7),
#           kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
# print (data['day_of_week'].corr(data['last_price']))

# %%
# filt_data = data[data['rooms'].between(0,5)]
grouped_data = data.groupby('type_floor')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['type_floor'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от типа этажа')
plt.xlabel('Расположение квартиры')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-info">Ниже всего оцениваются квартиры на 1м этаже. Ев верхнем этаже дороже, но дешевле промежуточного. Очевидно, категория 'пентхаус' настолько малочисленна, что не делает погоду в ценообразовании. Хотя они были бы в разы дороже. Можно было бы, ради иетереса рассмотреть дома с этажностью от 20.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Как в песне, "первый и последний этаж не предлагать". Традиционно, квартиры на первом и последнем этажах считаются самыми неудобными для жизни и это отражается на их стоимости.
# </div>

# %%
data_Piter_17 = data_Piter[data_Piter['floors_total']>17]
grouped_data = data_Piter_17.groupby('type_floor')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['type_floor'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от типа этажа. Питер 17 этажей и выше')
plt.xlabel('Расположение квартиры')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-info">Интуиция не подвела :) Как только мы ставим фильтр и убираем типовые 5 и 9 этажные дома, интерес к последнему этажу становится выше. Но по прежнему пентхаусы представляют очень малочисленную категорию, чтобы цена кв.м. значительно превысила цену на промежуточном этаже. Но. Уже не ниже.</div>

# %% [markdown]
# ### Цена от дня недели

# %%
grouped_data = data.groupby('day_of_week')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['day_of_week'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от дня недели')
plt.xlabel('День недели с понедельника')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %%
grouped_data = data_Piter_17.groupby('day_of_week')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['day_of_week'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от дня недели. Питер 17')
plt.xlabel('День недели с понедельника')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-info">Интересный небольшой пикв субботу для высотных новых домов . Видимо обусловлен тем, что люди на выходные больше просматривают объявлений и спрос выше на свежевыставленные квартиры. По общей базе расброса нет.</div>

# %% [markdown]
# день недели ни на что не влияет

# %% [markdown]
# ### Цена от месяца

# %%
grouped_data = data.groupby('mes_exposition')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['mes_exposition'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от месяца экспозиции')
plt.xlabel('Месяц экспонирования')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-info">Довольно интересная статистика. Можно выделить*провальные месяца* - январь, март, май, июнь, июль. Сложно объяснить. Просто факт. Очевидно объясняется снижением деловой активности на фоне отпусков. При этом август не попадает в это число, поскольку высок спрос перед началом учебного года. Аналочино предыдущему статистика по высотным домам в Питере значительно более выражена</div>

# %%
grouped_data = data_Piter_17.groupby('mes_exposition')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['mes_exposition'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от месяца экспозиции. Питер 17')
plt.xlabel('Месяц экспонирования')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %%
# data.plot(x='last_price', y='mes_exposition', xlim=(0, 25000000), ylim=(0,12),
#           kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
# print (data['mes_exposition'].corr(data['last_price']))

# %% [markdown]
# ### Цена от года

# %%
grouped_data = data.groupby('year_exposition')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['year_exposition'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от года экспозиции')
plt.xlabel('Год продажи')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-info">Ситуация с продажей недвидимости отображает общую экономическую ситуацию в стране. После кризиса 2014 цены упали. После чего начали последовательно восстанавливаться и расти. При этом расти начали за счет хорошего современного жилья. Что особенно отображает следующий график.</div>

# %%
grouped_data = data_Piter_17.groupby('year_exposition')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['year_exposition'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от года экспозиции. Питер 17')
plt.xlabel('Год продажи')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-info">Стабильный рост цены хорошего жилья даже несмотря на кризис 2014</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
# Отличный инсайд для заказчика. Молодец

# %%
# data.plot(x='last_price', y='year_exposition', xlim=(0, 25000000), ylim=(2013,2020),
#           kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
# print (data['year_exposition'].corr(data['last_price']))

# %%
# from pandas.plotting import scatter_matrix
# pd.plotting.scatter_matrix(data, figsize=(10, 10))

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Лучше после каждого раздела, графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи - так проще читать проект, поскольку будущим коллегам или заказчику не надо будет самим интерпретировать результаты каждого раздела, теста или графика.

# %% [markdown]
# ### Модификация проекта для выборочной проверки зависимости на интересующих параметрах

# %% [markdown]
# <div class="alert alert-info">так как существенных зависимостей не было обнаружено, родилась идея попробовать максимально сузить область рассмотрения. Следующий блок предлагает такой алгоритм: Нам предлагается ограничить рассматриваемую массу квартир. Для этого последовательно перебираются параметры. Предлагается брать из диапазона (Q1-Q3). Это необязательное условие. Но рекомендуемое, поскольку позволит убрать из рассмотрения выбросы. Можно четко зафиксировать какие-то параметры. Н-р взять только 3х комнатные квартиры в 5 этажках. Предыдущий анализ общей зависимости и выборочно высотных домов в Питере (от 17 этажей) показал, что это оправданный подход. Выводы могут сильно отличаться. В данном случае показана типовая реализация для нескольких параметром. Можно модифицировать метод в зависимости от желаемых параметров. В принципе ничто не мешает сделать опрос по всем параметрам, но вряд ли это представляет практический интерес. Зато точно охватит все возможные вариации. В частности рассмотренный вариант Питер 17 здесь тоже легко реализуется простановкой нужных параметров. </div>

# %%
import matplotlib.pyplot as plt
data_test = data[['floors_total','rooms','price_m2','dist', 'total_area', 'ceiling_height', 'parks_nearest']]
data_test.head(20)
q1 = data_test.quantile(0.25)
q3 = data_test.quantile(0.75)
user_inputs = {}
for column in data_test.columns:
    lower_bound = float(input(f"Введите нижнюю границу для {column}(между Q1={q1[column]} и Q3={q3[column]}): "))
    upper_bound = float(input(f"Введите верхнюю границу для {column}(между Q1={q1[column]} и Q3={q3[column]}): "))
    user_inputs[column] = (lower_bound, upper_bound)
filtered_data = data_test.copy()
# filtered_data.head()
for column, bounds in user_inputs.items():
    filtered_data = filtered_data[(filtered_data[column]>=bounds[0]) & (filtered_data[column] <= bounds[1])]
print(filtered_data.describe())
print()
print(filtered_data.corr())
pd.plotting.scatter_matrix(filtered_data, figsize=(15,15))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_129/2343068461.py in <module>
#       6 user_inputs = {}
#       7 for column in data_test.columns:
# ----> 8     lower_bound = float(input(f"Введите нижнюю границу для {column}(между Q1={q1[column]} и Q3={q3[column]}): "))
#       9     upper_bound = float(input(f"Введите верхнюю границу для {column}(между Q1={q1[column]} и Q3={q3[column]}): "))
#      10     user_inputs[column] = (lower_bound, upper_bound)
#
# /opt/conda/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     979                 "raw_input was called, but this frontend does not support input requests."
#     980             )
# --> 981         return self._input_request(
#     982             str(prompt),
#     983             self._parent_ident["shell"],
#
# ...

# %% [markdown]
# <div class="alert alert-info">Здесь не совсем интересно реализована аналитика. Но смысл в формировании среза из базы данных. По сути мы формируем новый массив, аналогичный рассмотренному data_Piter_17 и прогоняем его через блок аналитики.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Грамотная реализация

# %%
# colu40mns_for_histogram = []
# for i in range (2):
#     col_number = int(input(f"Введите номер{i+1}-го столбца для построения гистограммы (от 1 до10):"))
#     col_name = data_test.columns[col_number-1]
#     columns_for_histogram.append(col_name)
# x_column_name = data_test[2]
# y_column_name = data_test[4]
# filtered_data.plot(kind='scatter', x='price_m2', y='dist', xlim=(0,300000), alpha=0.03)
# plt.show()

# %%
# data_Piter.plot(y='price_m2', x='dist', xlim=(0, 30), ylim=(50000,200000),
#           kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
# print (data_Piter['price_m2'].corr(data['dist']))

# %%
# grouped_data = data.groupby('dist')['price_m2'].mean().reset_index()
# plt.figure(figsize=(8,6))
# plt.bar(grouped_data['dist'],grouped_data['price_m2'])
# plt.title('Средняя цена кв.м в зависимости от удаленности от центра')
# plt.xlabel('Рассторяние от центра')
# plt.ylabel('Средняя цена кв.м')
# plt.show()

# %% [markdown]
# Здесь очень хорошо видна тенденция снижения цены кв.м. с удалением от центра. Дальше расстояние практически не влияет. Ранее был график, на котором выводился Питер-неПитер по расстоянию. И вот на 25км Питер сменяется на пригород.

# %% [markdown]
# ### Населенные пункты с самой высокой ценой кв.м

# %% [markdown]
# Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
top_locations = data['locality_name_new'].value_counts().nlargest(20).index
filtered_data = data[data['locality_name_new'].isin(top_locations)]
# filtered_data = filtered_data.sort_values(by='price_m2')
print(pd.pivot_table(filtered_data, values='price_m2', index='locality_name_new', 
    aggfunc='mean').sort_values(by='price_m2', ascending=False))
print()
print ('Количество объявлений')
print(pd.pivot_table(filtered_data, values='price_m2', index='locality_name_new', 
    aggfunc='count').sort_values(by='price_m2', ascending=False))
# Out:
#                         price_m2
# locality_name_new
# Санкт-Петербург    114849.008793
# Пушкин             103125.819377
# Сестрорецк         101757.616831
# Кудрово             95324.930508
# Парголово           90175.913089
# Мурино              86087.512017
# Петергоф            84757.559602
# Бугры               80552.205877
# Шушары              78677.364318
# Новое Девяткино     76136.763542
# Колпино             75424.579112
# Ломоносов           72724.046466
# Красное Село        72148.588315
# Сертолово           69356.105634
# Гатчина             68746.146515
# Всеволожск          68654.473970
# Выборг              58141.909325
# Кириши              38875.779440
# Волхов              35087.680000
# Сланцы              18185.774286
#
# Количество объявлений
#                    price_m2
# locality_name_new
# Санкт-Петербург       15721
# Мурино                  590
# Кудрово                 472
# Шушары                  440
# Всеволожск              398
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
# Смотри, как можно в 1 строку:

# %%
data.groupby('locality_name_new').agg({'rooms':'count', 'price_m2':'mean'}) \
    .sort_values(by = 'price_m2', ascending = False) \
    .head(10)
# Out:
#                    rooms       price_m2
# locality_name_new
# Зеленогорск           24  115122.799583
# Санкт-Петербург    15721  114849.008793
# Репино                 4  104238.612500
# Пушкин               369  103125.819377
# Сестрорецк           183  101757.616831
# Лисий Нос              3  100660.816667
# Мистолово             11   98549.977273
# Левашово               1   96997.690000
# Кудрово              472   95324.930508
# Noname                49   94309.995102

# %% [markdown]
# <div class="alert alert-info">Использовал предложенный вариант, слегка исправив. А именно заменил медиану на среднюю (согдасно задания) и переупорядочил по цене, а не количеству объявлений. И что удивительно. Самые дорогие квартиры не в Питере, а Зеленогорске! Видимо это что-то элитное, типа нашего Рублевского ш. Аналогично Репино, Лисий Нор, Мистопово, Левашово. Прямо готовый гид для предпочитающих свежий воздух мегаполису и не стесненных в средствах :) </div>

# %% [markdown]
# ###  1.11. Зависимость цены по всей базе от удаленности от центра

# %%
grouped_data = data.groupby('dist')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['dist'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от удаленности от центра')
plt.xlabel('Рассторяние от центра')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-info">Здесь очень хорошо видна тенденция снижения цены кв.м. с удалением от центра. Дальше расстояние практически не влияет. Ранее был график, на котором выводился Питер-неПитер по расстоянию. И вот на 25км Питер сменяется на пригород. </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Отличная визуализация, но отсутствует срез по СПб. Добавь, пожалуйста

# %% [markdown]
# ### Зависимость цены в Санкт-Петербурге от удаленности от центра

# %%
grouped_data = data_Piter.groupby('dist')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['dist'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от удаленности от центра.Питер')
plt.xlabel('Рассторяние от центра')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Спасибо за правки. Здорово, что разобрались)

# %% [markdown]
# <div class="alert alert-info">Практически линейное снижение цены с удалением от центра. Небольшие всплески связаны с экслюзивным жильем.</div>

# %% [markdown]
# ### Зависимость цены в СПб области от удаленности от центра СПб

# %%
grouped_data = data_noPiter.groupby('dist')['price_m2'].mean().reset_index()
plt.figure(figsize=(8,6))
plt.bar(grouped_data['dist'],grouped_data['price_m2'])
plt.title('Средняя цена кв.м в зависимости от удаленности от центра.Область')
plt.xlabel('Рассторяние от центра')
plt.ylabel('Средняя цена кв.м')
plt.show()

# %% [markdown]
# <div class="alert alert-info">В области фактор удаленности от центра СПб значительно менее значим. Очевидно, гораздо важнее сам населенный пункт и его престижность, современность и т.п. Как выше было показано, цена кв.м. разительно отличается от населенного пункта. Если в Пушкине средняя цена практически совпадает с Питером, то в Сланцах она меньше в 6раз! В целом по области средний ценник примерно равен 70тр за кв.м., тогда как в Питере - 115тр. </div>

# %%
# top_locations = data['locality_name_new'].value_counts().nlargest(10).index
# filtered_data = data[data['locality_name_new'].isin(top_locations)]
# filtered_data = filtered_data.sort_values(by='price_m2')
# data_Piter.plot(y='price_m2', x='dist', xlim=(0, 30), ylim=(50000,200000),
#           kind='scatter', alpha=0.03, grid=True, sharex=False,figsize=(10,5))
# print ("Корреляция цены кв.м. от расстояния до центра:", data_Piter['price_m2'].corr(data['dist']))
# pd.pivot_table(data_Piter, values='price_m2', index='dist', 
#     aggfunc='mean').sort_values(by='price_m2', ascending=False)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Давай сделаем проект сильнее, и сделаем сводную таблицу (удалённость в км от центра Питера, и средняя цена на этом км). И уже по этой сводной таблице построим линейную или столбчатую диграмму для визуализации динамики цены относительно удалённости
# </div>

# %% [markdown]
# В целом прослеживается тенденция к понижению стоимости от расстояния. При этом зависимость нелинейная. Есть явный всплеск на 27км. Возможно это вызвано наличием какого-то элитного жил.центра или выброс. Можно провести доп. анализ для 27км. Возможно это выброс. Но даже без учета 27км зависимость нелинейная. Что по прежнему подтверждает, что влияние других факторов в сумме перевешивает, но тенденция понижения стоимости от расстояния на лицо.

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# В ходе исследования было рассмотрено огромное количество взаимосвязей. Вывод в том, что большое количество факторов влияет на стоимость квартиры(кв.м.) поэтому четкой зависимости не было выявлено ни по какой двойке параметров. Ну кроме очнвидной - общая площадь, жилая площадь, кол-во комнат, цена. Все остальнын факторы влияют слабо. Тем не менее влияют и поэтому предлагается след. классификация по корреляции: 0-0.1 связь отсутствует. 0.1-0.3 связь слабая. 0.3-0.5 - связь устойчивая. 0.5-1 очень сильная. Был создан алгоритм, позволяющий произвольным образом зафиксировать часть параметров, чтоб лучше отследить зависимость параметров для конкретного тип обьектов.

# %% [markdown]
# Возможно в проекте не достает текста, но это из-за недостатка времени и довольно сложно набирать текст без русской клавиатуры :) Так же крайне странно работает ядро. Постоянно пропадает какая та часть проекта. Частые сохранения лишь частично решают проблему. Готов выслущать замечания и доработать, при необходимости, проект. Также остался небольшой хвост с типом этажа. Сейчас уже глаз замылился. Похоже большой кусок кода пропал. Было отдельное исследование по заполнению пропусков в этажности дома. Там есть разные алноритмы. Медиану я сразу отсек. Там можно интересно поиграть в 5этажки. Они занимают 50% выборки. Исходя из этого можно было в 50% случаев с пропусками, где этаж квартиры от 1 до 5 проставить 5. в остальных случаях проставить этаж квартиры +1. Но это все не очень надо. У нам нет цели заполнить пропуски максимально возможно. Мы, делая таким образом, переносим одну зависомость на другую. И при анализе высотности дома от цены по сути будем оценивать высоту квартиры. но это все настолько слабо влияет, что лишено практического смысла. Гораздо интереснее, как мне кажется, получился алгоритм по сравнению определенных квартир со схожими параметрами. Его можно крутить по любому. Фиксировать все параметры, задавать узкие диапазоны для каких-то параметров, и по результатам делать выводы для конкретной квартиры. Это очень удобно для того, чтобы примерно оценить новую квартиру и дать рекомендации по ее оценке. Такой сервис мне был не известен. Я сам, оценивая свою квартиру, ищу объявления в своем доме :)

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно.
#
# ---
#
# Подскажи, пожалуйста, `Также остался небольшой хвост с типом этажа` - что именно тут имеешь ввиду?
# </div>

# %% [markdown]
# <div class="alert alert-info">Не удавалось написать код с аналитикой по типу этажа. Пытался выводить гистограммы. Но с переходом на столбчатые диаграммы все получилось </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Выгрузка данных
#
# 2) Проверка на дубликаты
#
# 3) Уменьшить range, чтобы рассмотреть пики
#
# 4) Построить графики зависимостей
#
# 5) В последнем шаге добавить линейную или столбчатую диаграмму
#
# 6) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи
#
# 7) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №2 </b>
#
#
# Отличная работа, осталось поправить один момент:
#
# ---
#
# Нужно поправить:
#
# 1) В последнем шаге срез по СПб
#
#
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №3__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [x]  Найдены пропущенные значения.
# - [x]  Пропущенные значения заполнены там, где это возможно.
# - [x]  Объяснено, какие пропущенные значения обнаружены.
# - [x]  В каждом столбце установлен корректный тип данных.
# - [x]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [x]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [x]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [x]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [x]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [x]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [x]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [x]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [x]  На каждом этапе сделаны промежуточные выводы.
# - [x]  В конце проекта сделан общий вывод.

# %% [markdown]
# <div class="alert alert-info"> У меня большая проблема с проектом.
#     1. У меня не работает ядро на сервере Яндекса. То есть не удается запустить Jupiter. Постоянно выводится сообщение, что он на ремонте. Мне удалось выкачать тетрадку и доделать проект локально. Надеюсь удастся и обратно его отправить.
#     2. У меня каждую минуту выскакивает сообщение, что сохранение прошло норм. Но блокнот похоже недействителен.Я удалил пару комментариев, но это не помогло.
#     3. Странным образом работает сам код. Периодически ячейки не выполняются. На нее нажимаешь и ничего не происходит. Вообще. Начинаешь подниматься выше и с какого-то момента начинает работать и после этого все ниже тоже работает. А может после нажатия перемотки так ничего и не заработать. Даже первые строчки кода.
#     4. У меня четкое ощущение, что часть кода постоянно пропадает. Я сейчас вычищал некоторые коментарии, которые по 3 раза написаны. и в тоже время вижу что часть алгоритмов отсутствует. Или вообше на полуслове обрываются.
#     5. Очень все странно. Возможно как-то связано, что я сейчас в Англии.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Спасибо, что подсветил. Это точно не связано с твоим гео-нахождением. Но в последнее время Юпитер действительно "вел себя плохо". Но уже вроде починили. Если у тебя сейчас также все работает некорректно - рекомендую обратиться к куратору и в тех.поддержку

# %% [markdown]
# Сейчас Юпитер работает корректно. Но ошибка по прежнему "Notebook validation failed "

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Это должно пройти
